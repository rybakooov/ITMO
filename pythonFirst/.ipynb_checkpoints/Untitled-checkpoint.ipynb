# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import datasets, linear_model
# %matplotlib inline

# %%
def get_data(url): # парсинг страницы с данными
  page = pd.read_html(url, encoding='CP1251')
  header = page[6].drop(12).T
  header = header.iloc[1]
  header[0]='Номер УИК'
  data=page[7].drop(12).T
  data.columns=header
  data.reset_index()
  return data


def to_numeric(data): #функция парсит все данные в числа, убирает символы
  data.iloc[:,0]=[int(i.split()[1][1:]) for i in data.iloc[:,0]]
  for i in range(1,12):
    data.iloc[:,i]=pd.to_numeric(data.iloc[:,i])
  for i in range(12,15):
    l=[]
    perc=[]
    for a in data.iloc[:,i]:
      a=a.split()
      l.append(int(a[0]))
      perc.append(float(a[1][:-2]))
    data.iloc[:,i]=l
    data['Процентов за ' + str(data.columns.values[i])] = perc
  return data

# %%
url11 = 'http://www.st-petersburg.vybory.izbirkom.ru/region/region/st-petersburg?action=show&tvd=27820001217417&vrn=27820001217413&region=78&global=&sub_region=78&prver=0&pronetvd=null&vibid=27820001217435&type=222'
url27 = 'http://www.st-petersburg.vybory.izbirkom.ru/region/region/st-petersburg?action=show&tvd=27820001217417&vrn=27820001217413&region=78&global=&sub_region=78&prver=0&pronetvd=null&vibid=27820001217429&type=222'


data = get_data(url11)
data1 =get_data(url27)
data = to_numeric(data)
data1 = to_numeric(data1)
data = data.append(data1)
data.head()
# Out:
# 1  Номер УИК  \
# 0        512
# 1        513
# 2        514
# 3        515
# 4        516
#
# 1  Число избирателей, внесенных в список избирателей на момент окончания голосования  \
# 0                                               1852
# 1                                               1319
# 2                                               1599
# 3                                               2478
# 4                                               1961
#
# 1  Число избирательных бюллетеней, полученных участковой избирательной комиссией  \
# 0                                               1500
# 1                                               1000
# 2                                               1500
# 3                                               2000
# 4                                               1500
#
# 1  Число избирательных бюллетеней, выданных избирателям в помещении для голосования в день голосования  \
# 0                                                430
# 1                                                306
# 2                                                335
# 3                                                430
# 4                                                485
#
# 1  Число избирательных бюллетеней, выданных избирателям, проголосовавшим вне помещения для голосования  \
# 0                                                  3
# 1                                                  6
# 2                                                 29
# 3                                                 15
# 4                                                  5
#
# 1  Число погашенных избирательных бюллетеней  \
# 0                                       1067
# 1                                        688
# 2                                       1136
# 3                                       1555
# 4                                       1010
#
# 1  Число избирательных бюллетеней, содержащихся в переносных ящиках для голосования  \
# 0                                                  3
# 1                                                  6
# 2                                                 29
# 3                                                 15
# 4                                                  5
#
# 1  Число избирательных бюллетеней, содержащихся в стационарных ящиках для голосования  \
# 0                                                430
# 1                                                306
# 2                                                335
# 3                                                430
# 4                                                485
#
# 1  Число недействительных избирательных бюллетеней  \
# 0                                               14
# 1                                                2
# 2                                                7
# 3                                               11
# 4                                                9
#
# 1  Число действительных избирательных бюллетеней  \
# 0                                            419
# 1                                            310
# 2                                            357
# 3                                            434
# 4                                            481
#
# 1  Число утраченных избирательных бюллетеней  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# 4                                          0
#
# 1  Число избирательных бюллетеней, не учтенных при получении  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# 1  Амосов Михаил Иванович  Беглов Александр Дмитриевич  \
# 0                      92                          230
# 1                      59                          186
# 2                      63                          221
# 3                      60                          291
# 4                      85                          308
#
# 1  Тихонова Надежда Геннадьевна  Процентов за Амосов Михаил Иванович  \
# 0                            97                                 21.2
# 1                            65                                 18.9
# 2                            73                                 17.3
# 3                            83                                 13.4
# 4                            88                                 17.3
#
# 1  Процентов за Беглов Александр Дмитриевич  \
# 0                                      53.1
# 1                                      59.6
# 2                                      60.7
# 3                                      65.3
# 4                                      62.8
#
# 1  Процентов за Тихонова Надежда Геннадьевна
# 0                                       22.4
# 1                                       20.8
# 2                                       20.0
# 3                                       18.6
# 4                                       17.9

# %%
def plot(x,y,label):
  x=np.array(x).reshape(-1,1)
  y=np.array(y).reshape(-1,1)
  l=LinearRegression().fit(x,y)
  c=l.coef_[0][0]
  xmin=min(data.iloc[:,1])
  xmax=max(data.iloc[:,1])
  ls=np.linspace(xmin,xmax)
  plt.plot(ls,ls*c,color='red')
  plt.scatter(x,y,linewidth=1)
  plt.legend(['МНК','Голоса за '+label])
  print('MSE =',mean_squared_error(y,x*c))
  print('R2 score = ',r2_score(y,x*c))
  plt.show()
  print()

plot(data.iloc[:,1],data.iloc[:,12], 'Амосова')
plot(data.iloc[:,1],data.iloc[:,13],'Беглова')
plot(data.iloc[:,1],data.iloc[:,14],'Тихонова')
# Out:
# MSE = 1492.9056231721258
# R2 score =  0.36566300388852235
# MSE = 30487.27698960775
# R2 score =  0.02940368133972393
# MSE = 2523.992348843976
# R2 score =  0.2557743312401438
